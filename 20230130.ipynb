# %%
# 분석 라이브러리 
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# 경고 문구 미표시
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # url 조합

# %%
base_url = "http://openapi.seoul.go.kr:8088"
file_type = "json"
service_name = "BukChonInOutPeopleInfo"
start = 1
end = 5  

import os
url = os.path.join(base_url, file_type, service_name, str(start), str(end))
print(url)
# Out:
# http://openapi.seoul.go.kr:8088\json\BukChonInOutPeopleInfo\1\5

# %%
url = "/".join([base_url, api_key, file_type, service_name, str(start), str(end)])
print(url)
# Out:
# http://openapi.seoul.go.kr:8088/4a6d4e62656f6b6b393842426f5359/json/BukChonInOutPeopleInfo/1/5

# %%
"/".join(["a", "b", "c"])
# Out:
# 'a/b/c'

# %% [markdown]
# # concat

# %%
text_data = '{"BukChonInOutPeopleInfo":{"list_total_count":18793,"RESULT":{"CODE":"INFO-000","MESSAGE":"정상 처리되었습니다"},"row":[{"DEVICEID":2.0,"DEVICENAME":"계동길 69","DESCRIPTION":"계동교회 앞","STARTTIME":"2022-08-30 10:00:39","ENDTIME":"2022-08-30 10:10:39","INCOUNT":5039.0,"OUTCOUNT":2044.0},{"DEVICEID":2.0,"DEVICENAME":"계동길 69","DESCRIPTION":"계동교회 앞","STARTTIME":"2022-09-01 06:30:40","ENDTIME":"2022-09-01 06:40:40","INCOUNT":819.0,"OUTCOUNT":2115.0},{"DEVICEID":2.0,"DEVICENAME":"계동길 69","DESCRIPTION":"계동교회 앞","STARTTIME":"2022-09-03 01:10:39","ENDTIME":"2022-09-03 01:20:39","INCOUNT":105.0,"OUTCOUNT":377.0},{"DEVICEID":2.0,"DEVICENAME":"계동길 69","DESCRIPTION":"계동교회 앞","STARTTIME":"2022-09-07 20:40:40","ENDTIME":"2022-09-07 20:50:40","INCOUNT":13052.0,"OUTCOUNT":17942.0},{"DEVICEID":2.0,"DEVICENAME":"계동길 69","DESCRIPTION":"계동교회 앞","STARTTIME":"2022-09-09 09:50:39","ENDTIME":"2022-09-09 10:00:39","INCOUNT":4380.0,"OUTCOUNT":4960.0}]}}'
text_data
# Out:
# '{"BukChonInOutPeopleInfo":{"list_total_count":18793,"RESULT":{"CODE":"INFO-000","MESSAGE":"정상 처리되었습니다"},"row":[{"DEVICEID":2.0,"DEVICENAME":"계동길 69","DESCRIPTION":"계동교회 앞","STARTTIME":"2022-08-30 10:00:39","ENDTIME":"2022-08-30 10:10:39","INCOUNT":5039.0,"OUTCOUNT":2044.0},{"DEVICEID":2.0,"DEVICENAME":"계동길 69","DESCRIPTION":"계동교회 앞","STARTTIME":"2022-09-01 06:30:40","ENDTIME":"2022-09-01 06:40:40","INCOUNT":819.0,"OUTCOUNT":2115.0},{"DEVICEID":2.0,"DEVICENAME":"계동길 69","DESCRIPTION":"계동교회 앞","STARTTIME":"2022-09-03 01:10:39","ENDTIME":"2022-09-03 01:20:39","INCOUNT":105.0,"OUTCOUNT":377.0},{"DEVICEID":2.0,"DEVICENAME":"계동길 69","DESCRIPTION":"계동교회 앞","STARTTIME":"2022-09-07 20:40:40","ENDTIME":"2022-09-07 20:50:40","INCOUNT":13052.0,"OUTCOUNT":17942.0},{"DEVICEID":2.0,"DEVICENAME":"계동길 69","DESCRIPTION":"계동교회 앞","STARTTIME":"2022-09-09 09:50:39","ENDTIME":"2022-09-09 10:00:39","INCOUNT":4380.0,"OUTCOUNT":4960.0}]}}'

# %%
import json

dict_data = json.loads(text_data)
dict_data
# Out:
# {'BukChonInOutPeopleInfo': {'list_total_count': 18793,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'DEVICEID': 2.0,
#     'DEVICENAME': '계동길 69',
#     'DESCRIPTION': '계동교회 앞',
#     'STARTTIME': '2022-08-30 10:00:39',
#     'ENDTIME': '2022-08-30 10:10:39',
#     'INCOUNT': 5039.0,
#     'OUTCOUNT': 2044.0},
#    {'DEVICEID': 2.0,
#     'DEVICENAME': '계동길 69',
#     'DESCRIPTION': '계동교회 앞',
#     'STARTTIME': '2022-09-01 06:30:40',
#     'ENDTIME': '2022-09-01 06:40:40',
#     'INCOUNT': 819.0,
#     'OUTCOUNT': 2115.0},
#    {'DEVICEID': 2.0,
#     'DEVICENAME': '계동길 69',
#     'DESCRIPTION': '계동교회 앞',
#     'STARTTIME': '2022-09-03 01:10:39',
#     'ENDTIME': '2022-09-03 01:20:39',
#     'INCOUNT': 105.0,
#     'OUTCOUNT': 377.0},
#    {'DEVICEID': 2.0,
#     'DEVICENAME': '계동길 69',
#     'DESCRIPTION': '계동교회 앞',
#     'STARTTIME': '2022-09-07 20:40:40',
#     'ENDTIME': '2022-09-07 20:50:40',
#     'INCOUNT': 13052.0,
#     'OUTCOUNT': 17942.0},
# ...

# %%
dict_data.update(dict_data)

# %%
d1 = {"a":1}
d2 = {"b":2}

d1.update(d2)

# %%
d1
# Out:
# {'a': 1, 'b': 2}

# %%
dict_data['BukChonInOutPeopleInfo']['row'] + [1, 2, 3]
# Out:
# [{'DEVICEID': 2.0,
#   'DEVICENAME': '계동길 69',
#   'DESCRIPTION': '계동교회 앞',
#   'STARTTIME': '2022-08-30 10:00:39',
#   'ENDTIME': '2022-08-30 10:10:39',
#   'INCOUNT': 5039.0,
#   'OUTCOUNT': 2044.0},
#  {'DEVICEID': 2.0,
#   'DEVICENAME': '계동길 69',
#   'DESCRIPTION': '계동교회 앞',
#   'STARTTIME': '2022-09-01 06:30:40',
#   'ENDTIME': '2022-09-01 06:40:40',
#   'INCOUNT': 819.0,
#   'OUTCOUNT': 2115.0},
#  {'DEVICEID': 2.0,
#   'DEVICENAME': '계동길 69',
#   'DESCRIPTION': '계동교회 앞',
#   'STARTTIME': '2022-09-03 01:10:39',
#   'ENDTIME': '2022-09-03 01:20:39',
#   'INCOUNT': 105.0,
#   'OUTCOUNT': 377.0},
#  {'DEVICEID': 2.0,
#   'DEVICENAME': '계동길 69',
#   'DESCRIPTION': '계동교회 앞',
#   'STARTTIME': '2022-09-07 20:40:40',
#   'ENDTIME': '2022-09-07 20:50:40',
#   'INCOUNT': 13052.0,
#   'OUTCOUNT': 17942.0},
#  {'DEVICEID': 2.0,
#   'DEVICENAME': '계동길 69',
#   'DESCRIPTION': '계동교회 앞',
#   'STARTTIME': '2022-09-09 09:50:39',
#   'ENDTIME': '2022-09-09 10:00:39',
#   'INCOUNT': 4380.0,
# ...

# %%
df = pd.DataFrame(dict_data['BukChonInOutPeopleInfo']['row'])
print(df.shape)
df.head()
# Out:
# (5, 7)
#    DEVICEID DEVICENAME DESCRIPTION            STARTTIME              ENDTIME  \
# 0       2.0     계동길 69      계동교회 앞  2022-08-30 10:00:39  2022-08-30 10:10:39
# 1       2.0     계동길 69      계동교회 앞  2022-09-01 06:30:40  2022-09-01 06:40:40
# 2       2.0     계동길 69      계동교회 앞  2022-09-03 01:10:39  2022-09-03 01:20:39
# 3       2.0     계동길 69      계동교회 앞  2022-09-07 20:40:40  2022-09-07 20:50:40
# 4       2.0     계동길 69      계동교회 앞  2022-09-09 09:50:39  2022-09-09 10:00:39
#
#    INCOUNT  OUTCOUNT
# 0   5039.0    2044.0
# 1    819.0    2115.0
# 2    105.0     377.0
# 3  13052.0   17942.0
# 4   4380.0    4960.0

# %%
pd.concat([df, df], axis=0)
# Out:
#    DEVICEID DEVICENAME DESCRIPTION            STARTTIME              ENDTIME  \
# 0       2.0     계동길 69      계동교회 앞  2022-08-30 10:00:39  2022-08-30 10:10:39
# 1       2.0     계동길 69      계동교회 앞  2022-09-01 06:30:40  2022-09-01 06:40:40
# 2       2.0     계동길 69      계동교회 앞  2022-09-03 01:10:39  2022-09-03 01:20:39
# 3       2.0     계동길 69      계동교회 앞  2022-09-07 20:40:40  2022-09-07 20:50:40
# 4       2.0     계동길 69      계동교회 앞  2022-09-09 09:50:39  2022-09-09 10:00:39
# 0       2.0     계동길 69      계동교회 앞  2022-08-30 10:00:39  2022-08-30 10:10:39
# 1       2.0     계동길 69      계동교회 앞  2022-09-01 06:30:40  2022-09-01 06:40:40
# 2       2.0     계동길 69      계동교회 앞  2022-09-03 01:10:39  2022-09-03 01:20:39
# 3       2.0     계동길 69      계동교회 앞  2022-09-07 20:40:40  2022-09-07 20:50:40
# 4       2.0     계동길 69      계동교회 앞  2022-09-09 09:50:39  2022-09-09 10:00:39
#
#    INCOUNT  OUTCOUNT
# 0   5039.0    2044.0
# 1    819.0    2115.0
# 2    105.0     377.0
# 3  13052.0   17942.0
# ...

# %%
df = pd.concat([df, df], axis=0)
df = df.reset_index(drop=True)
df
# Out:
#    DEVICEID DEVICENAME DESCRIPTION            STARTTIME              ENDTIME  \
# 0       2.0     계동길 69      계동교회 앞  2022-08-30 10:00:39  2022-08-30 10:10:39
# 1       2.0     계동길 69      계동교회 앞  2022-09-01 06:30:40  2022-09-01 06:40:40
# 2       2.0     계동길 69      계동교회 앞  2022-09-03 01:10:39  2022-09-03 01:20:39
# 3       2.0     계동길 69      계동교회 앞  2022-09-07 20:40:40  2022-09-07 20:50:40
# 4       2.0     계동길 69      계동교회 앞  2022-09-09 09:50:39  2022-09-09 10:00:39
# 5       2.0     계동길 69      계동교회 앞  2022-08-30 10:00:39  2022-08-30 10:10:39
# 6       2.0     계동길 69      계동교회 앞  2022-09-01 06:30:40  2022-09-01 06:40:40
# 7       2.0     계동길 69      계동교회 앞  2022-09-03 01:10:39  2022-09-03 01:20:39
# 8       2.0     계동길 69      계동교회 앞  2022-09-07 20:40:40  2022-09-07 20:50:40
# 9       2.0     계동길 69      계동교회 앞  2022-09-09 09:50:39  2022-09-09 10:00:39
#
#    INCOUNT  OUTCOUNT
# 0   5039.0    2044.0
# 1    819.0    2115.0
# 2    105.0     377.0
# 3  13052.0   17942.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DEVICEID     10 non-null     float64
#  1   DEVICENAME   10 non-null     object
#  2   DESCRIPTION  10 non-null     object
#  3   STARTTIME    10 non-null     object
#  4   ENDTIME      10 non-null     object
#  5   INCOUNT      10 non-null     float64
#  6   OUTCOUNT     10 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 688.0+ bytes

# %% [markdown]
# # strftime 함수

# %%
df['STARTTIME'] = pd.to_datetime(df['STARTTIME'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DEVICEID     10 non-null     float64
#  1   DEVICENAME   10 non-null     object
#  2   DESCRIPTION  10 non-null     object
#  3   STARTTIME    10 non-null     datetime64[ns]
#  4   ENDTIME      10 non-null     object
#  5   INCOUNT      10 non-null     float64
#  6   OUTCOUNT     10 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 688.0+ bytes

# %%
df['STARTTIME'].dt.hour
# Out:
# 0    10
# 1     6
# 2     1
# 3    20
# 4     9
# 5    10
# 6     6
# 7     1
# 8    20
# 9     9
# Name: STARTTIME, dtype: int64

# %%
2022-09-09 09:50:39

# %%
df['STARTTIME'].dt.strftime('%Y-%m-%d %H:%M:%S')
# Out:
# 0    2022-08-30 10:00:39
# 1    2022-09-01 06:30:40
# 2    2022-09-03 01:10:39
# 3    2022-09-07 20:40:40
# 4    2022-09-09 09:50:39
# 5    2022-08-30 10:00:39
# 6    2022-09-01 06:30:40
# 7    2022-09-03 01:10:39
# 8    2022-09-07 20:40:40
# 9    2022-09-09 09:50:39
# Name: STARTTIME, dtype: object

# %%
df['STARTTIME'] = df['STARTTIME'].dt.strftime('%Y-%m-%d %H:%M:%S')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DEVICEID     10 non-null     float64
#  1   DEVICENAME   10 non-null     object
#  2   DESCRIPTION  10 non-null     object
#  3   STARTTIME    10 non-null     object
#  4   ENDTIME      10 non-null     object
#  5   INCOUNT      10 non-null     float64
#  6   OUTCOUNT     10 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 688.0+ bytes

# %%
df
# Out:
#    DEVICEID DEVICENAME DESCRIPTION            STARTTIME              ENDTIME  \
# 0       2.0     계동길 69      계동교회 앞  2022-08-30 10:00:39  2022-08-30 10:10:39
# 1       2.0     계동길 69      계동교회 앞  2022-09-01 06:30:40  2022-09-01 06:40:40
# 2       2.0     계동길 69      계동교회 앞  2022-09-03 01:10:39  2022-09-03 01:20:39
# 3       2.0     계동길 69      계동교회 앞  2022-09-07 20:40:40  2022-09-07 20:50:40
# 4       2.0     계동길 69      계동교회 앞  2022-09-09 09:50:39  2022-09-09 10:00:39
# 5       2.0     계동길 69      계동교회 앞  2022-08-30 10:00:39  2022-08-30 10:10:39
# 6       2.0     계동길 69      계동교회 앞  2022-09-01 06:30:40  2022-09-01 06:40:40
# 7       2.0     계동길 69      계동교회 앞  2022-09-03 01:10:39  2022-09-03 01:20:39
# 8       2.0     계동길 69      계동교회 앞  2022-09-07 20:40:40  2022-09-07 20:50:40
# 9       2.0     계동길 69      계동교회 앞  2022-09-09 09:50:39  2022-09-09 10:00:39
#
#    INCOUNT  OUTCOUNT
# 0   5039.0    2044.0
# 1    819.0    2115.0
# 2    105.0     377.0
# 3  13052.0   17942.0
# ...

# %% [markdown]
# # 여러 개의 그래프를 동시에...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(data=df, x='INCOUNT');

# %%
fig, axes = plt.subplots(1, 2)
axes[0].plot(np.arange(10))
axes[1].hist([1,1,1,0,0,3])
# Out:
# (array([2., 0., 0., 3., 0., 0., 0., 0., 0., 1.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
print(fig)
# Out:
# Figure(432x288)

# %%
print(axes)
# Out:
# [<AxesSubplot:> <AxesSubplot:>]

# %%
import seaborn as sns

fig, axes = plt.subplots(2, 3, figsize=(15, 5))

sns.histplot(data=df, x='INCOUNT', ax=axes[0, 0])
sns.boxplot(data=df, y='OUTCOUNT', ax=axes[1, 2])

plt.show()

# %%
df_final = pd.read_csv('bukchon.csv')
df_final
# Out:
#        DEVICEID DEVICENAME DESCRIPTION            STARTTIME  \
# 0           2.0     계동길 69      계동교회 앞  2022-11-30 21:10:41
# 1           1.0   율곡로3길 50      덕성여고 앞  2022-11-30 21:10:41
# 2           2.0     계동길 69      계동교회 앞  2022-11-30 21:20:41
# 3           1.0   율곡로3길 50      덕성여고 앞  2022-11-30 21:20:41
# 4           2.0     계동길 69      계동교회 앞  2022-11-30 21:30:41
# ...         ...        ...         ...                  ...
# 29254       1.0   율곡로3길 50      덕성여고 앞  2023-01-29 14:20:40
# 29255       2.0     계동길 69      계동교회 앞  2023-01-29 14:30:40
# 29256       1.0   율곡로3길 50      덕성여고 앞  2023-01-29 14:30:40
# 29257       2.0     계동길 69      계동교회 앞  2023-01-29 14:40:40
# 29258       1.0   율곡로3길 50      덕성여고 앞  2023-01-29 14:40:40
#
#                    ENDTIME  INCOUNT  OUTCOUNT
# 0      2022-11-30 21:20:41   9386.0   13749.0
# 1      2022-11-30 21:20:41   7903.0    5279.0
# 2      2022-11-30 21:30:41   9398.0   13776.0
# 3      2022-11-30 21:30:41   7927.0    5312.0
# ...

# %%
df_final['STARTTIME'] = pd.to_datetime(df_final['STARTTIME'])
df_final['HOUR'] = df_final['STARTTIME'].dt.hour
df_final.head()
# Out:
#    DEVICEID DEVICENAME DESCRIPTION           STARTTIME              ENDTIME  \
# 0       2.0     계동길 69      계동교회 앞 2022-11-30 21:10:41  2022-11-30 21:20:41
# 1       1.0   율곡로3길 50      덕성여고 앞 2022-11-30 21:10:41  2022-11-30 21:20:41
# 2       2.0     계동길 69      계동교회 앞 2022-11-30 21:20:41  2022-11-30 21:30:41
# 3       1.0   율곡로3길 50      덕성여고 앞 2022-11-30 21:20:41  2022-11-30 21:30:41
# 4       2.0     계동길 69      계동교회 앞 2022-11-30 21:30:41  2022-11-30 21:40:41
#
#    INCOUNT  OUTCOUNT  HOUR
# 0   9386.0   13749.0    21
# 1   7903.0    5279.0    21
# 2   9398.0   13776.0    21
# 3   7927.0    5312.0    21
# 4   9414.0   13800.0    21

# %%
df_final.sort_values(by=['DESCRIPTION', 'INCOUNT'], ascending=[True, False])
# Out:
#       DEVICEID DEVICENAME DESCRIPTION           STARTTIME  \
# 8995       2.0     계동길 69      계동교회 앞 2022-11-16 23:40:41
# 8992       2.0     계동길 69      계동교회 앞 2022-11-16 23:30:41
# 8989       2.0     계동길 69      계동교회 앞 2022-11-16 23:20:41
# 8986       2.0     계동길 69      계동교회 앞 2022-11-16 23:10:41
# 8983       2.0     계동길 69      계동교회 앞 2022-11-16 23:00:41
# ...        ...        ...         ...                 ...
# 5722       4.0  북촌로5가길 38   삼청파출소 사잇길 2022-11-10 00:00:40
# 5725       4.0  북촌로5가길 38   삼청파출소 사잇길 2022-11-10 00:10:40
# 8033       4.0  북촌로5가길 38   삼청파출소 사잇길 2022-11-15 00:00:39
# 8037       4.0  북촌로5가길 38   삼청파출소 사잇길 2022-11-15 00:10:40
# 8042       4.0  북촌로5가길 38   삼청파출소 사잇길 2022-11-15 00:20:39
#
#                   ENDTIME  INCOUNT  OUTCOUNT  HOUR
# 8995  2022-11-16 23:50:41  25507.0   29223.0    23
# 8992  2022-11-16 23:40:41  25488.0   29180.0    23
# 8989  2022-11-16 23:30:41  25477.0   29161.0    23
# 8986  2022-11-16 23:20:41  25449.0   29124.0    23
# ...

# %%
df_final.sort_index(ascending=False)
# Out:
#        DEVICEID DEVICENAME DESCRIPTION           STARTTIME  \
# 29258       1.0   율곡로3길 50      덕성여고 앞 2023-01-29 14:40:40
# 29257       2.0     계동길 69      계동교회 앞 2023-01-29 14:40:40
# 29256       1.0   율곡로3길 50      덕성여고 앞 2023-01-29 14:30:40
# 29255       2.0     계동길 69      계동교회 앞 2023-01-29 14:30:40
# 29254       1.0   율곡로3길 50      덕성여고 앞 2023-01-29 14:20:40
# ...         ...        ...         ...                 ...
# 4           2.0     계동길 69      계동교회 앞 2022-11-30 21:30:41
# 3           1.0   율곡로3길 50      덕성여고 앞 2022-11-30 21:20:41
# 2           2.0     계동길 69      계동교회 앞 2022-11-30 21:20:41
# 1           1.0   율곡로3길 50      덕성여고 앞 2022-11-30 21:10:41
# 0           2.0     계동길 69      계동교회 앞 2022-11-30 21:10:41
#
#                    ENDTIME  INCOUNT  OUTCOUNT  HOUR
# 29258  2023-01-29 14:50:40   1800.0    1537.0    14
# 29257  2023-01-29 14:50:40   1755.0    2473.0    14
# 29256  2023-01-29 14:40:40   1670.0    1436.0    14
# ...

# %%
gby = df_final.groupby(['DESCRIPTION', 'HOUR'])[['INCOUNT', 'OUTCOUNT']].mean()
gby
# Out:
#                       INCOUNT     OUTCOUNT
# DESCRIPTION HOUR
# 계동교회 앞      0       47.284722    74.560764
#             1      110.465278   190.524306
#             2      162.704861   310.137153
#             3      210.692708   422.083333
#             4      264.133681   538.868056
# ...                       ...          ...
# 삼청파출소 사잇길   19    4708.282051  5468.435897
#             20    4974.717949  5721.455128
#             21    5162.435897  5916.044872
#             22    5265.121795  6028.134615
#             23    5309.338462  6080.230769
#
# [72 rows x 2 columns]

# %% [markdown]
# ### 이것을 x축을 HOUR index로 0시부터 23시까지 나타내고, y축을 INCOUNT, OUTCOUNT, 그리고 각각의 line그래프를 DESCRIPTION에 나타난 장소로 해서 보고싶습니다. 어떻게 해야 좋을까요?

# %%
gby.index.get_level_values(0)
# Out:
# Index(['계동교회 앞', '계동교회 앞', '계동교회 앞', '계동교회 앞', '계동교회 앞', '계동교회 앞', '계동교회 앞',
#        '계동교회 앞', '계동교회 앞', '계동교회 앞', '계동교회 앞', '계동교회 앞', '계동교회 앞', '계동교회 앞',
#        '계동교회 앞', '계동교회 앞', '계동교회 앞', '계동교회 앞', '계동교회 앞', '계동교회 앞', '계동교회 앞',
#        '계동교회 앞', '계동교회 앞', '계동교회 앞', '덕성여고 앞', '덕성여고 앞', '덕성여고 앞', '덕성여고 앞',
#        '덕성여고 앞', '덕성여고 앞', '덕성여고 앞', '덕성여고 앞', '덕성여고 앞', '덕성여고 앞', '덕성여고 앞',
#        '덕성여고 앞', '덕성여고 앞', '덕성여고 앞', '덕성여고 앞', '덕성여고 앞', '덕성여고 앞', '덕성여고 앞',
#        '덕성여고 앞', '덕성여고 앞', '덕성여고 앞', '덕성여고 앞', '덕성여고 앞', '덕성여고 앞', '삼청파출소 사잇길',
#        '삼청파출소 사잇길', '삼청파출소 사잇길', '삼청파출소 사잇길', '삼청파출소 사잇길', '삼청파출소 사잇길',
#        '삼청파출소 사잇길', '삼청파출소 사잇길', '삼청파출소 사잇길', '삼청파출소 사잇길', '삼청파출소 사잇길',
#        '삼청파출소 사잇길', '삼청파출소 사잇길', '삼청파출소 사잇길', '삼청파출소 사잇길', '삼청파출소 사잇길',
#        '삼청파출소 사잇길', '삼청파출소 사잇길', '삼청파출소 사잇길', '삼청파출소 사잇길', '삼청파출소 사잇길',
#        '삼청파출소 사잇길', '삼청파출소 사잇길', '삼청파출소 사잇길'],
#       dtype='object', name='DESCRIPTION')

# %%
gby.index.get_level_values(0) == '계동교회 앞'
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
df1 = gby.loc[gby.index.get_level_values(0) == '계동교회 앞']
# df1.index = df1.index.get_level_values(1)

df1 = df1.reset_index()

# %%
df2 = gby.loc[gby.index.get_level_values(0) == '삼청파출소 사잇길']
# df2.index = df2.index.get_level_values(1)
df2 = df2.reset_index()

# %%
df3 = gby.loc[gby.index.get_level_values(0) == '덕성여고 앞']
# df2.index = df2.index.get_level_values(1)
df3 = df3.reset_index()

# %%
df = pd.concat([df1, df2, df3])
df = df.reset_index(drop=True)
df
# Out:
#    DESCRIPTION  HOUR      INCOUNT     OUTCOUNT
# 0       계동교회 앞     0    47.284722    74.560764
# 1       계동교회 앞     1   110.465278   190.524306
# 2       계동교회 앞     2   162.704861   310.137153
# 3       계동교회 앞     3   210.692708   422.083333
# 4       계동교회 앞     4   264.133681   538.868056
# ..         ...   ...          ...          ...
# 67      덕성여고 앞    19  6132.979920  5303.893574
# 68      덕성여고 앞    20  6467.271084  5690.544177
# 69      덕성여고 앞    21  6682.873494  6003.578313
# 70      덕성여고 앞    22  6851.590361  6206.377510
# 71      덕성여고 앞    23  6951.298795  6292.069880
#
# [72 rows x 4 columns]

# %%
# Windows
font_path = "C:/Windows/Fonts/malgun.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
sns.lineplot(data=df, x='HOUR', hue='DESCRIPTION', y='INCOUNT')
# Out:
# <AxesSubplot:xlabel='HOUR', ylabel='INCOUNT'>

# %%
sns.lineplot(data=df, x='HOUR', y='INCOUNT')
sns.lineplot(data=df, x='HOUR', y='OUTCOUNT')
# Out:
# <AxesSubplot:xlabel='HOUR', ylabel='INCOUNT'>
