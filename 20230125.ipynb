# %%
# 분석 라이브러리 
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# 경고 문구 미표시
import warnings
warnings.filterwarnings(action='ignore')

# %%
df = pd.read_csv('iris.data.csv', header=None)
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.columns = ['Sepal_length','Sepal_width','Petal_length','Petal_width','Species']
df.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# # [질문 1]  .replace를 사용할 때, 'str'를 추가해야 할 때와 아닐 때를 구분하는 방법이 있을까요?

# %% [markdown]
# ### Case 1. Pandas 라이브러리의 df.replace 메서드 함수

# %%
df.replace("Iris-", "")
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width         Species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.replace(['Iris-setosa',  'Iris-versicolor', 'Iris-virginica'], ['setosa', 'versicolor', 'virginica'], inplace=True)
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = df.replace(['Iris-setosa',  'Iris-versicolor', 'Iris-virginica'], ['setosa', 'versicolor', 'virginica'])

# %%
df
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width         Species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Case 2. Pandas 라이브러리의 str 접근자

# %%
df['Species'].str

# %%
df['Species'] = df['Species'].str.replace("Iris-", "")
df
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Case 3. Python 문자열 처리 함수

# %%
df['Species']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
name_list = []
for name in df['Species']:
    name_list.append(name.replace("Iris-", ""))
    
name_list[:5]
# Out:
# ['setosa', 'setosa', 'setosa', 'setosa', 'setosa']

# %%
df['Species'] = name_list
df
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
tmp = pd.DataFrame(pd.date_range(start='2023-01-01', end='2023-01-31'), columns=['date'])
tmp['date'].dt.year
# Out:
# 0     2023
# 1     2023
# 2     2023
# 3     2023
# 4     2023
# 5     2023
# 6     2023
# 7     2023
# 8     2023
# 9     2023
# 10    2023
# 11    2023
# 12    2023
# 13    2023
# 14    2023
# 15    2023
# 16    2023
# 17    2023
# 18    2023
# 19    2023
# 20    2023
# 21    2023
# 22    2023
# 23    2023
# 24    2023
# 25    2023
# 26    2023
# 27    2023
# 28    2023
# 29    2023
# 30    2023
# Name: date, dtype: int64

# %%
tmp['value'] = np.random.normal(0, 1, size=(31,))
tmp
# Out:
#          date     value
# 0  2023-01-01  0.443782
# 1  2023-01-02  0.336693
# 2  2023-01-03  0.320965
# 3  2023-01-04  1.875922
# 4  2023-01-05 -0.680598
# 5  2023-01-06 -1.410879
# 6  2023-01-07 -0.846559
# 7  2023-01-08 -0.859901
# 8  2023-01-09  0.277459
# 9  2023-01-10 -0.144043
# 10 2023-01-11 -1.134700
# 11 2023-01-12 -1.114263
# 12 2023-01-13 -1.278694
# 13 2023-01-14  0.636132
# 14 2023-01-15  0.929945
# 15 2023-01-16  0.098538
# 16 2023-01-17  0.345144
# 17 2023-01-18  0.766978
# 18 2023-01-19  2.328685
# 19 2023-01-20 -0.316668
# 20 2023-01-21 -0.527167
# 21 2023-01-22  0.179133
# 22 2023-01-23 -0.305906
# 23 2023-01-24 -0.386468
# 24 2023-01-25  0.234920
# 25 2023-01-26  0.977067
# 26 2023-01-27 -0.090375
# 27 2023-01-28 -0.293935
# 28 2023-01-29  0.197618
# 29 2023-01-30  1.414631
# 30 2023-01-31 -0.183285

# %%
plt.figure(figsize=(15, 5))
sns.lineplot(x='date', y='value', data=tmp)
plt.xticks(rotation=90)
plt.show()

# %%
tmp['date'] = tmp['date'].astype(str)
tmp['date'].str[:4]
# Out:
# 0     2023
# 1     2023
# 2     2023
# 3     2023
# 4     2023
# 5     2023
# 6     2023
# 7     2023
# 8     2023
# 9     2023
# 10    2023
# 11    2023
# 12    2023
# 13    2023
# 14    2023
# 15    2023
# 16    2023
# 17    2023
# 18    2023
# 19    2023
# 20    2023
# 21    2023
# 22    2023
# 23    2023
# 24    2023
# 25    2023
# 26    2023
# 27    2023
# 28    2023
# 29    2023
# 30    2023
# Name: date, dtype: object

# %%
tmp['date'].str.split("-", expand=True)[0]
# Out:
# 0     2023
# 1     2023
# 2     2023
# 3     2023
# 4     2023
# 5     2023
# 6     2023
# 7     2023
# 8     2023
# 9     2023
# 10    2023
# 11    2023
# 12    2023
# 13    2023
# 14    2023
# 15    2023
# 16    2023
# 17    2023
# 18    2023
# 19    2023
# 20    2023
# 21    2023
# 22    2023
# 23    2023
# 24    2023
# 25    2023
# 26    2023
# 27    2023
# 28    2023
# 29    2023
# 30    2023
# Name: 0, dtype: object

# %%
tmp['date'].replace(r"-[0-9]{2}-[0-9]{2}", "", regex=True)
# Out:
# 0     2023
# 1     2023
# 2     2023
# 3     2023
# 4     2023
# 5     2023
# 6     2023
# 7     2023
# 8     2023
# 9     2023
# 10    2023
# 11    2023
# 12    2023
# 13    2023
# 14    2023
# 15    2023
# 16    2023
# 17    2023
# 18    2023
# 19    2023
# 20    2023
# 21    2023
# 22    2023
# 23    2023
# 24    2023
# 25    2023
# 26    2023
# 27    2023
# 28    2023
# 29    2023
# 30    2023
# Name: date, dtype: object

# %%
tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    31 non-null     object
# dtypes: object(1)
# memory usage: 376.0+ bytes

# %% [markdown]
# # [질문 2] pandas bar 그래프 x축이 너무 촘촘할 때 x축 텍스트 빈도수를 어떻게 줄이나요?

# %%
df['Sepal_length'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# 데이터를 샘플링하고, 샘플 데이터를 시각화
df['Sepal_length'].sample(20).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# 데이터를 구간으로 나누고, 구간에 해당하는 빈도수를 시각화
df['Sepal_length'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[   df['Species'].str.match("setosa")   ]
# Out:
#     Sepal_length  Sepal_width  Petal_length  Petal_width Species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...
